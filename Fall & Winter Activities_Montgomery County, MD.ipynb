# %%
#import the pandas library
import pandas as pd

# %%
#create reference to and read the csv into a pandas dataframe
md_activities_df = pd.read_csv('Recreation_Fall_Winter_Programs.csv')

#print the first five rows of data to the screen
md_activities_df.head()
# Out:
#             Session        Primary Category  Secondary Category  \
# 0  Winter 2020/2021         Health/Wellness                 NaN
# 1  Winter 2020/2021         Health/Wellness                Yoga
# 2  Winter 2020/2021             Educational  Specialty Programs
# 3  Winter 2020/2021                 Fitness   Strength Training
# 4  Winter 2020/2021  Therapeutic Recreation                Yoga
#
#                                        Activity Name  \
# 0                         Boost Your Brain Power 55+
# 1      Hatha Yoga and Stress Management Beg/Cont 50+
# 2  Thurgood Marshall: A Trail-Blazing Civil Right...
# 3                                Strength and Toning
# 4                                     TR Yoga Basics
#
#                                          Description  Activity Number  \
# 0  Maintaining brain fitness is a critical factor...            93616
# 1  Learn to handle the stresses of daily life wit...            96850
# 2  Thurgood Marshall: A Trail-Blazing Civil Right...           100925
# 3  Get the look and feel you desire by joining th...            99249
# 4  For individuals with disabilities. Introduces ...            98582
#
#         Ages                                  Location  Address     City  ...  \
# 0  55 and up  Rec Virtual Room 8 at Recreation Virtual  Virtual  Virtual  ...
# 1  50 and up  Rec Virtual Room 1 at Recreation Virtual  Virtual  Virtual  ...
# 2  55 and up  Rec Virtual Room 5 at Recreation Virtual  Virtual  Virtual  ...
# 3  18 and up  Rec Virtual Room 2 at Recreation Virtual  Virtual  Virtual  ...
# 4  15 and up  Rec Virtual Room 6 at Recreation Virtual  Virtual  Virtual  ...
#
#           Activity Facility  Start Date    End Date      Start Time  \
# 0  Recreation Virtual Rooms  11/19/2020  11/19/2020  1/0/1900 12:00
# 1  Recreation Virtual Rooms   1/15/2021   3/19/2021  1/0/1900 10:00
# 2  Recreation Virtual Rooms  12/15/2020  12/15/2020  1/0/1900 11:00
# 3  Recreation Virtual Rooms   1/11/2021    3/8/2021  1/0/1900 10:00
# 4  Recreation Virtual Rooms   1/20/2021   2/24/2021  1/0/1900 16:00
#
#          End Time Sessions Days of the Week  Fee Status  \
# 0  1/0/1900 12:30        1               Th    0   Open
# 1  1/0/1900 11:00       10                F  100   Open
# 2  1/0/1900 12:00        1                T    0   Open
# 3  1/0/1900 10:45        7                M   65   Open
# 4  1/0/1900 17:00        6                W   60   Open
#
#                     Address/Location
# 0  Virtual\nVirtual, Virtual Virtual
# 1  Virtual\nVirtual, Virtual Virtual
# 2  Virtual\nVirtual, Virtual Virtual
# 3  Virtual\nVirtual, Virtual Virtual
# 4  Virtual\nVirtual, Virtual Virtual
#
# [5 rows x 22 columns]

# %%
#list and count the different types of activities offerered 

df['Primary Category'].value_counts()
# Out:
# Fitness                   22
# Health/Wellness           21
# Therapeutic Recreation    15
# Educational               14
# Martial Arts              12
# Dance                     11
# Sports                    10
# Music                      9
# Aquatics                   9
# Art                        7
# Cooking                    4
# Events                     4
# Virtual                    2
# STEAM                      2
# Games                      1
# Nature & Outdoors          1
# Nutrition                  1
# Historical & Cultural      1
# Name: Primary Category, dtype: int64

# %%
#extract locations of activities

df ['Location'].value_counts()
# Out:
# Rec Virtual Room 6 at Recreation Virtual    24
# Rec Virtual Room 1 at Recreation Virtual    18
# Virtual room unspecified                    18
# Rec Virtual Room 2 at Recreation Virtual    17
# Rec Virtual Room 5 at Recreation Virtual    14
# Rec Virtual Room 3 at Recreation Virtual    13
# Rec Virtual Room 7 at Recreation Virtual    12
# Rec Virtual Room 8 at Recreation Virtual     8
# Rec Virtual Room 4 at Recreation Virtual     8
# Location unspecified                         4
# Kennedy Shriver Aquatic Center               2
# Germantown Indoor Swim Center                2
# Olney Swim Center                            2
# Martin Luther King Jr. Swim Center           2
# Meet at the Main Entrance                    1
# Virtual Room                                 1
# Name: Location, dtype: int64

# %%
#convert list of "music" activities into dataframe

# Convert the city_counts Series into a DataFrame
city_loss_counts_df = pd.DataFrame(city_counts)
city_loss_counts_df.head()

# %%
#convert list of "nature & outdoors" activities into a dataframe

# Convert the city_counts Series into a DataFrame
city_loss_counts_df = pd.DataFrame(city_counts)
city_loss_counts_df.head()

# %%
#activities offered on Saturdays


# Filter data to incidents that caused Property or Contents Loss
loss_df = fires_cleaned_df.loc[(fires_cleaned_df["Property Loss"] > 0) |
                               (fires_cleaned_df["Contents Loss"] > 0) , :]
loss_df.head()

# %%
#filter data to read all in person activities


# Filter data to incidents that caused Property or Contents Loss
loss_df = fires_cleaned_df.loc[(fires_cleaned_df["Property Loss"] > 0) |
                               (fires_cleaned_df["Contents Loss"] > 0) , :]
loss_df.head()
